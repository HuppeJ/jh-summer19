# %% [markdown]
# # Title

# %% [markdown]
# ## Smaller title

# %%
letterList = ["a", "b", "c", "d", "e", "f"]
for letter in letterList:
    print(letter)
# Out:
# a
# b
# c
# d
# e
# f

# %%
# Comment in Code cell
for letter in letterList:
    print(letter + ",")
# Out:
# a,
# b,
# c,
# d,
# e,
# f,

# %%
# Comment in Code cell
for letter in letterList: 
    print(letter + "-")
# Out:
# a-
# b-
# c-
# d-
# e-
# f-

# %% [markdown]
# ### Chapter 2
